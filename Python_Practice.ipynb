# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshitha8073/Datascience-R/blob/main/Python_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Python Pandas Practice***

# %%
import pandas as pd

# %%
#Read csv files
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d4d2ac40-2172-4917-8ccc-cae394190f96" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d4d2ac40-2172-4917-8ccc-cae394190f96">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('mtcars.csv')
df
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
#List first 5 records
df.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %%
#Getting first 3 rows from df
df_first_3 = df.head(3)

# %%
#Printing df_first_3
print(df_first_3)
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1

# %%
#Reading first 10 records
df.head(10)
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7  24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8  22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9  19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4

# %%
#Data Types
df.dtypes
# Out:
# mpg     float64
# cyl       int64
# disp    float64
# hp        int64
# drat    float64
# wt      float64
# qsec    float64
# vs        int64
# am        int64
# gear      int64
# carb      int64
# dtype: object

# %%
#Total number of elements
df.size
# Out:
# 352

# %%
#Number of rows and columns
df.shape
# Out:
# (32, 11)

# %%
#Columns
df.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=32, step=1),
#  Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#         'carb'],
#        dtype='object')]

# %%
df.values
# Out:
# array([[ 21.   ,   6.   , 160.   , 110.   ,   3.9  ,   2.62 ,  16.46 ,
#           0.   ,   1.   ,   4.   ,   4.   ],
#        [ 21.   ,   6.   , 160.   , 110.   ,   3.9  ,   2.875,  17.02 ,
#           0.   ,   1.   ,   4.   ,   4.   ],
#        [ 22.8  ,   4.   , 108.   ,  93.   ,   3.85 ,   2.32 ,  18.61 ,
#           1.   ,   1.   ,   4.   ,   1.   ],
#        [ 21.4  ,   6.   , 258.   , 110.   ,   3.08 ,   3.215,  19.44 ,
#           1.   ,   0.   ,   3.   ,   1.   ],
#        [ 18.7  ,   8.   , 360.   , 175.   ,   3.15 ,   3.44 ,  17.02 ,
#           0.   ,   0.   ,   3.   ,   2.   ],
#        [ 18.1  ,   6.   , 225.   , 105.   ,   2.76 ,   3.46 ,  20.22 ,
#           1.   ,   0.   ,   3.   ,   1.   ],
#        [ 14.3  ,   8.   , 360.   , 245.   ,   3.21 ,   3.57 ,  15.84 ,
#           0.   ,   0.   ,   3.   ,   4.   ],
#        [ 24.4  ,   4.   , 146.7  ,  62.   ,   3.69 ,   3.19 ,  20.   ,
#           1.   ,   0.   ,   4.   ,   2.   ],
# ...

# %%
#Dimension
df.ndim
# Out:
# 2

# %%
#Number of records in dataset
df.shape
# Out:
# (32, 11)

# %%
df.shape[0]
# Out:
# 32

# %%
df.shape[1]
# Out:
# 11

# %%
#Number of columns
df.columns
# Out:
# Index(['mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear',
#        'carb'],
#       dtype='object')

# %%
#Describes the data frame
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
# Maximun and minimum values
df.max()
# Out:
# mpg      33.900
# cyl       8.000
# disp    472.000
# hp      335.000
# drat      4.930
# wt        5.424
# qsec     22.900
# vs        1.000
# am        1.000
# gear      5.000
# carb      8.000
# dtype: float64

# %%
df.min()
# Out:
# mpg     10.400
# cyl      4.000
# disp    71.100
# hp      52.000
# drat     2.760
# wt       1.513
# qsec    14.500
# vs       0.000
# am       0.000
# gear     3.000
# carb     1.000
# dtype: float64

# %%
#Mean
df.mean()
# Out:
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
#Standard Deviation
df.std()
# Out:
# mpg       6.026948
# cyl       1.785922
# disp    123.938694
# hp       68.562868
# drat      0.534679
# wt        0.978457
# qsec      1.786943
# vs        0.504016
# am        0.498991
# gear      0.737804
# carb      1.615200
# dtype: float64

# %%
# Mean of first 50 records in the dataset
df.head(50).mean()
# Out:
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
df_sub = df.head(50)
df_sub
# Out:
#      mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0   21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1   21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2   22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3   21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4   18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2
# 5   18.1    6  225.0  105  2.76  3.460  20.22   1   0     3     1
# 6   14.3    8  360.0  245  3.21  3.570  15.84   0   0     3     4
# 7   24.4    4  146.7   62  3.69  3.190  20.00   1   0     4     2
# 8   22.8    4  140.8   95  3.92  3.150  22.90   1   0     4     2
# 9   19.2    6  167.6  123  3.92  3.440  18.30   1   0     4     4
# 10  17.8    6  167.6  123  3.92  3.440  18.90   1   0     4     4
# 11  16.4    8  275.8  180  3.07  4.070  17.40   0   0     3     3
# 12  17.3    8  275.8  180  3.07  3.730  17.60   0   0     3     3
# ...

# %%
df_sub.mean()
# Out:
# mpg      20.090625
# cyl       6.187500
# disp    230.721875
# hp      146.687500
# drat      3.596563
# wt        3.217250
# qsec     17.848750
# vs        0.437500
# am        0.406250
# gear      3.687500
# carb      2.812500
# dtype: float64

# %%
df.mpg
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
df['mpg']
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
df[['mpg']]
# Out:
#      mpg
# 0   21.0
# 1   21.0
# 2   22.8
# 3   21.4
# 4   18.7
# 5   18.1
# 6   14.3
# 7   24.4
# 8   22.8
# 9   19.2
# 10  17.8
# 11  16.4
# 12  17.3
# 13  15.2
# 14  10.4
# 15  10.4
# 16  14.7
# 17  32.4
# 18  30.4
# 19  33.9
# 20  21.5
# 21  15.5
# 22  15.2
# 23  13.3
# 24  19.2
# 25  27.3
# 26  26.0
# 27  30.4
# 28  15.8
# 29  19.7
# 30  15.0
# 31  21.4

# %%
#Calculating basic statistics for cyl column
df[['cyl']]
# Out:
#     cyl
# 0     6
# 1     6
# 2     4
# 3     6
# 4     8
# 5     6
# 6     8
# 7     4
# 8     4
# 9     6
# 10    6
# 11    8
# 12    8
# 13    8
# 14    8
# 15    8
# 16    8
# 17    4
# 18    4
# 19    4
# 20    4
# 21    8
# 22    8
# 23    8
# 24    8
# 25    4
# 26    4
# 27    4
# 28    8
# 29    6
# 30    8
# 31    4

# %%
df[['cyl']].describe()
# Out:
#              cyl
# count  32.000000
# mean    6.187500
# std     1.785922
# min     4.000000
# 25%     4.000000
# 50%     6.000000
# 75%     8.000000
# max     8.000000

# %%
#To find out how many values are there in cyl colunm(using count method)
df.cyl.count()
# Out:
# 32

# %%
#Calculate average cyl

# %%
df.cyl.mean()
# Out:
# 6.1875

# %%
#Read csv files
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-eb2c8c26-41e4-4b7f-9b08-177cfe82bdfc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-eb2c8c26-41e4-4b7f-9b08-177cfe82bdfc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Position_Salaries.csv')
df
# Out:
#             Position  Level   Salary
# 0   Business Analyst      1    45000
# 1  Junior Consultant      2    50000
# 2  Senior Consultant      3    60000
# 3            Manager      4    80000
# 4    Country Manager      5   110000
# 5     Region Manager      6   150000
# 6            Partner      7   200000
# 7     Senior Partner      8   300000
# 8            C-level      9   500000
# 9                CEO     10  1000000

# %%
df.groupby(['Position']).mean()
# Out:
#                    Level     Salary
# Position
# Business Analyst     1.0    45000.0
# C-level              9.0   500000.0
# CEO                 10.0  1000000.0
# Country Manager      5.0   110000.0
# Junior Consultant    2.0    50000.0
# Manager              4.0    80000.0
# Partner              7.0   200000.0
# Region Manager       6.0   150000.0
# Senior Consultant    3.0    60000.0
# Senior Partner       8.0   300000.0

# %%
df['Salary'] >120000
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# Name: Salary, dtype: bool

# %%
df[df['Salary'] >120000]
# Out:
#          Position  Level   Salary
# 5  Region Manager      6   150000
# 6         Partner      7   200000
# 7  Senior Partner      8   300000
# 8         C-level      9   500000
# 9             CEO     10  1000000

# %%
#To select more than 1 column
df[['Position','Salary']]
# Out:
#             Position   Salary
# 0   Business Analyst    45000
# 1  Junior Consultant    50000
# 2  Senior Consultant    60000
# 3            Manager    80000
# 4    Country Manager   110000
# 5     Region Manager   150000
# 6            Partner   200000
# 7     Senior Partner   300000
# 8            C-level   500000
# 9                CEO  1000000

# %%
#First row of the data frame
df.iloc[0]
# Out:
# Position    Business Analyst
# Level                      1
# Salary                 45000
# Name: 0, dtype: object

# %%
# Last row of the data frame
df.iloc[-1]
# Out:
# Position        CEO
# Level            10
# Salary      1000000
# Name: 9, dtype: object

# %%
#First column of the data frame
df.iloc[:,0]
# Out:
# 0     Business Analyst
# 1    Junior Consultant
# 2    Senior Consultant
# 3              Manager
# 4      Country Manager
# 5       Region Manager
# 6              Partner
# 7       Senior Partner
# 8              C-level
# 9                  CEO
# Name: Position, dtype: object

# %%
#Last column of the data frame
df.iloc[:,-1]
# Out:
# 0      45000
# 1      50000
# 2      60000
# 3      80000
# 4     110000
# 5     150000
# 6     200000
# 7     300000
# 8     500000
# 9    1000000
# Name: Salary, dtype: int64

# %%
#First 7 rows
df.iloc[0:7]
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000
# 5     Region Manager      6  150000
# 6            Partner      7  200000

# %%
#First 2 columns
df.iloc[:,0:2]
# Out:
#             Position  Level
# 0   Business Analyst      1
# 1  Junior Consultant      2
# 2  Senior Consultant      3
# 3            Manager      4
# 4    Country Manager      5
# 5     Region Manager      6
# 6            Partner      7
# 7     Senior Partner      8
# 8            C-level      9
# 9                CEO     10

# %%
#first and second rows and first 2 columns
df.iloc[1:3, 0:2]
# Out:
#             Position  Level
# 1  Junior Consultant      2
# 2  Senior Consultant      3

# %%
#Aggregate Functions
df[['Position','Salary']]
# Out:
#             Position   Salary
# 0   Business Analyst    45000
# 1  Junior Consultant    50000
# 2  Senior Consultant    60000
# 3            Manager    80000
# 4    Country Manager   110000
# 5     Region Manager   150000
# 6            Partner   200000
# 7     Senior Partner   300000
# 8            C-level   500000
# 9                CEO  1000000

# %%
df[['Level','Salary']].agg(['min','mean','max'])
# Out:
#       Level     Salary
# min     1.0    45000.0
# mean    5.5   249500.0
# max    10.0  1000000.0

# %%
df[['Position','Salary']].agg(['min','mean','max'])
# Out:
#               Position     Salary
# min   Business Analyst    45000.0
# mean               NaN   249500.0
# max     Senior Partner  1000000.0
